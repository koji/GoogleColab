# %% [markdown]
# <a href="https://colab.research.google.com/github/koji/GoogleColab/blob/main/SDXL_Lightning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://huggingface.co/spaces/AP123/SDXL-Lightning
# Out:
# Cloning into 'SDXL-Lightning'...
# remote: Enumerating objects: 44, done.
# remote: Counting objects: 100% (40/40), done.
# remote: Compressing objects: 100% (39/39), done.
# remote: Total 44 (delta 19), reused 0 (delta 0), pack-reused 4
# Unpacking objects: 100% (44/44), 18.41 KiB | 1.53 MiB/s, done.

# %%
# !pip install transformers diffusers accelerate gradio
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.37.2)
# Collecting diffusers
#   Downloading diffusers-0.26.3-py3-none-any.whl (1.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 12.1 MB/s eta 0:00:00
# Collecting accelerate
#   Downloading accelerate-0.27.2-py3-none-any.whl (279 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 280.0/280.0 kB 13.9 MB/s eta 0:00:00
# Collecting gradio
#   Downloading gradio-4.19.2-py3-none-any.whl (16.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.9/16.9 MB 57.2 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.20.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.12.25)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.15.2)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.2)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.10/dist-packages (from diffusers) (7.0.1)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from diffusers) (9.4.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: torch>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (2.1.0+cu121)
# Collecting aiofiles<24.0,>=22.0 (from gradio)
#   Downloading aiofiles-23.2.1-py3-none-any.whl (15 kB)
# Requirement already satisfied: altair<6.0,>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (4.2.2)
# Collecting fastapi (from gradio)
#   Downloading fastapi-0.109.2-py3-none-any.whl (92 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.1/92.1 kB 11.3 MB/s eta 0:00:00
# Collecting ffmpy (from gradio)
#   Downloading ffmpy-0.3.2.tar.gz (5.5 kB)
#   Preparing metadata (setup.py) ... done
# Collecting gradio-client==0.10.1 (from gradio)
#   Downloading gradio_client-0.10.1-py3-none-any.whl (307 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.9/307.9 kB 41.7 MB/s eta 0:00:00
# Collecting httpx>=0.24.1 (from gradio)
#   Downloading httpx-0.27.0-py3-none-any.whl (75 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 7.7 MB/s eta 0:00:00
# Requirement already satisfied: importlib-resources<7.0,>=1.3 in /usr/local/lib/python3.10/dist-packages (from gradio) (6.1.1)
# Requirement already satisfied: jinja2<4.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (3.1.3)
# Requirement already satisfied: markupsafe~=2.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (2.1.5)
# Requirement already satisfied: matplotlib~=3.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (3.7.1)
# Collecting orjson~=3.0 (from gradio)
#   Downloading orjson-3.9.15-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (138 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.5/138.5 kB 21.2 MB/s eta 0:00:00
# Requirement already satisfied: pandas<3.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (1.5.3)
# Requirement already satisfied: pydantic>=2.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (2.6.1)
# Collecting pydub (from gradio)
#   Downloading pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Collecting python-multipart>=0.0.9 (from gradio)
#   Downloading python_multipart-0.0.9-py3-none-any.whl (22 kB)
# Collecting ruff>=0.2.2 (from gradio)
#   Downloading ruff-0.2.2-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 75.0 MB/s eta 0:00:00
# Collecting semantic-version~=2.0 (from gradio)
#   Downloading semantic_version-2.10.0-py2.py3-none-any.whl (15 kB)
# Collecting tomlkit==0.12.0 (from gradio)
#   Downloading tomlkit-0.12.0-py3-none-any.whl (37 kB)
# Requirement already satisfied: typer[all]<1.0,>=0.9 in /usr/local/lib/python3.10/dist-packages (from gradio) (0.9.0)
# Requirement already satisfied: typing-extensions~=4.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (4.9.0)
# Collecting uvicorn>=0.14.0 (from gradio)
#   Downloading uvicorn-0.27.1-py3-none-any.whl (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.8/60.8 kB 9.3 MB/s eta 0:00:00
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from gradio-client==0.10.1->gradio) (2023.6.0)
# Collecting websockets<12.0,>=10.0 (from gradio-client==0.10.1->gradio)
#   Downloading websockets-11.0.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (129 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.9/129.9 kB 9.7 MB/s eta 0:00:00
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.10/dist-packages (from altair<6.0,>=4.2.0->gradio) (0.4)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.10/dist-packages (from altair<6.0,>=4.2.0->gradio) (4.19.2)
# Requirement already satisfied: toolz in /usr/local/lib/python3.10/dist-packages (from altair<6.0,>=4.2.0->gradio) (0.12.1)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx>=0.24.1->gradio) (3.7.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx>=0.24.1->gradio) (2024.2.2)
# Collecting httpcore==1.* (from httpx>=0.24.1->gradio)
#   Downloading httpcore-1.0.4-py3-none-any.whl (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.8/77.8 kB 6.7 MB/s eta 0:00:00
# Requirement already satisfied: idna in /usr/local/lib/python3.10/dist-packages (from httpx>=0.24.1->gradio) (3.6)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx>=0.24.1->gradio) (1.3.0)
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx>=0.24.1->gradio)
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 8.0 MB/s eta 0:00:00
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.0->gradio) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.0->gradio) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.0->gradio) (4.49.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.0->gradio) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.0->gradio) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.0->gradio) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas<3.0,>=1.0->gradio) (2023.4)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic>=2.0->gradio) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.2 in /usr/local/lib/python3.10/dist-packages (from pydantic>=2.0->gradio) (2.16.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.2.1)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (2.1.0)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.10/dist-packages (from typer[all]<1.0,>=0.9->gradio) (8.1.7)
# Collecting colorama<0.5.0,>=0.4.3 (from typer[all]<1.0,>=0.9->gradio)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Collecting shellingham<2.0.0,>=1.3.0 (from typer[all]<1.0,>=0.9->gradio)
#   Downloading shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Requirement already satisfied: rich<14.0.0,>=10.11.0 in /usr/local/lib/python3.10/dist-packages (from typer[all]<1.0,>=0.9->gradio) (13.7.0)
# Collecting starlette<0.37.0,>=0.36.3 (from fastapi->gradio)
#   Downloading starlette-0.36.3-py3-none-any.whl (71 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.5/71.5 kB 11.3 MB/s eta 0:00:00
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata->diffusers) (3.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio) (0.33.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio) (0.18.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib~=3.0->gradio) (1.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich<14.0.0,>=10.11.0->typer[all]<1.0,>=0.9->gradio) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich<14.0.0,>=10.11.0->typer[all]<1.0,>=0.9->gradio) (2.16.1)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio->httpx>=0.24.1->gradio) (1.2.0)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.10.0->accelerate) (1.3.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich<14.0.0,>=10.11.0->typer[all]<1.0,>=0.9->gradio) (0.1.2)
# Building wheels for collected packages: ffmpy
#   Building wheel for ffmpy (setup.py) ... done
#   Created wheel for ffmpy: filename=ffmpy-0.3.2-py3-none-any.whl size=5584 sha256=68a84cf7662dc9348c91ee677d4c4e6779b96a5bd3357c8845d9ee9e63d5b579
#   Stored in directory: /root/.cache/pip/wheels/bd/65/9a/671fc6dcde07d4418df0c592f8df512b26d7a0029c2a23dd81
# Successfully built ffmpy
# Installing collected packages: pydub, ffmpy, websockets, tomlkit, shellingham, semantic-version, ruff, python-multipart, orjson, h11, colorama, aiofiles, uvicorn, starlette, httpcore, httpx, fastapi, diffusers, accelerate, gradio-client, gradio
# Successfully installed accelerate-0.27.2 aiofiles-23.2.1 colorama-0.4.6 diffusers-0.26.3 fastapi-0.109.2 ffmpy-0.3.2 gradio-4.19.2 gradio-client-0.10.1 h11-0.14.0 httpcore-1.0.4 httpx-0.27.0 orjson-3.9.15 pydub-0.25.1 python-multipart-0.0.9 ruff-0.2.2 semantic-version-2.10.0 shellingham-1.5.4 starlette-0.36.3 tomlkit-0.12.0 uvicorn-0.27.1 websockets-11.0.3

# %%
# !ls
# Out:
# sample_data  SDXL-Lightning

# %%
cd SDXL-Lightning
# Out:
# /content/SDXL-Lightning

# %%
# !ls
# Out:
# app.py	README.md  requirements.txt  safety_checker.py	style.css

# %%
# !pip install spaces
# Out:
# Collecting spaces
#   Downloading spaces-0.23.2-py3-none-any.whl (16 kB)
# Requirement already satisfied: gradio in /usr/local/lib/python3.10/dist-packages (from spaces) (4.19.2)
# Requirement already satisfied: httpx>=0.20 in /usr/local/lib/python3.10/dist-packages (from spaces) (0.27.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from spaces) (23.2)
# Requirement already satisfied: psutil<6,>=2 in /usr/local/lib/python3.10/dist-packages (from spaces) (5.9.5)
# Requirement already satisfied: pydantic<3,>=1 in /usr/local/lib/python3.10/dist-packages (from spaces) (2.6.1)
# Requirement already satisfied: requests<3.0,>=2.19 in /usr/local/lib/python3.10/dist-packages (from spaces) (2.31.0)
# Requirement already satisfied: typing-extensions<5,>=4 in /usr/local/lib/python3.10/dist-packages (from spaces) (4.9.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx>=0.20->spaces) (3.7.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx>=0.20->spaces) (2024.2.2)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx>=0.20->spaces) (1.0.4)
# Requirement already satisfied: idna in /usr/local/lib/python3.10/dist-packages (from httpx>=0.20->spaces) (3.6)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx>=0.20->spaces) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx>=0.20->spaces) (0.14.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1->spaces) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.2 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1->spaces) (2.16.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.19->spaces) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.19->spaces) (2.0.7)
# Requirement already satisfied: aiofiles<24.0,>=22.0 in /usr/local/lib/python3.10/dist-packages (from gradio->spaces) (23.2.1)
# Requirement already satisfied: altair<6.0,>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from gradio->spaces) (4.2.2)
# Requirement already satisfied: fastapi in /usr/local/lib/python3.10/dist-packages (from gradio->spaces) (0.109.2)
# Requirement already satisfied: ffmpy in /usr/local/lib/python3.10/dist-packages (from gradio->spaces) (0.3.2)
# Requirement already satisfied: gradio-client==0.10.1 in /usr/local/lib/python3.10/dist-packages (from gradio->spaces) (0.10.1)
# Requirement already satisfied: huggingface-hub>=0.19.3 in /usr/local/lib/python3.10/dist-packages (from gradio->spaces) (0.20.3)
# Requirement already satisfied: importlib-resources<7.0,>=1.3 in /usr/local/lib/python3.10/dist-packages (from gradio->spaces) (6.1.1)
# Requirement already satisfied: jinja2<4.0 in /usr/local/lib/python3.10/dist-packages (from gradio->spaces) (3.1.3)
# Requirement already satisfied: markupsafe~=2.0 in /usr/local/lib/python3.10/dist-packages (from gradio->spaces) (2.1.5)
# Requirement already satisfied: matplotlib~=3.0 in /usr/local/lib/python3.10/dist-packages (from gradio->spaces) (3.7.1)
# Requirement already satisfied: numpy~=1.0 in /usr/local/lib/python3.10/dist-packages (from gradio->spaces) (1.25.2)
# Requirement already satisfied: orjson~=3.0 in /usr/local/lib/python3.10/dist-packages (from gradio->spaces) (3.9.15)
# Requirement already satisfied: pandas<3.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from gradio->spaces) (1.5.3)
# Requirement already satisfied: pillow<11.0,>=8.0 in /usr/local/lib/python3.10/dist-packages (from gradio->spaces) (9.4.0)
# Requirement already satisfied: pydub in /usr/local/lib/python3.10/dist-packages (from gradio->spaces) (0.25.1)
# Requirement already satisfied: python-multipart>=0.0.9 in /usr/local/lib/python3.10/dist-packages (from gradio->spaces) (0.0.9)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in /usr/local/lib/python3.10/dist-packages (from gradio->spaces) (6.0.1)
# Requirement already satisfied: ruff>=0.2.2 in /usr/local/lib/python3.10/dist-packages (from gradio->spaces) (0.2.2)
# Requirement already satisfied: semantic-version~=2.0 in /usr/local/lib/python3.10/dist-packages (from gradio->spaces) (2.10.0)
# Requirement already satisfied: tomlkit==0.12.0 in /usr/local/lib/python3.10/dist-packages (from gradio->spaces) (0.12.0)
# Requirement already satisfied: typer[all]<1.0,>=0.9 in /usr/local/lib/python3.10/dist-packages (from gradio->spaces) (0.9.0)
# Requirement already satisfied: uvicorn>=0.14.0 in /usr/local/lib/python3.10/dist-packages (from gradio->spaces) (0.27.1)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from gradio-client==0.10.1->gradio->spaces) (2023.6.0)
# Requirement already satisfied: websockets<12.0,>=10.0 in /usr/local/lib/python3.10/dist-packages (from gradio-client==0.10.1->gradio->spaces) (11.0.3)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.10/dist-packages (from altair<6.0,>=4.2.0->gradio->spaces) (0.4)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.10/dist-packages (from altair<6.0,>=4.2.0->gradio->spaces) (4.19.2)
# Requirement already satisfied: toolz in /usr/local/lib/python3.10/dist-packages (from altair<6.0,>=4.2.0->gradio->spaces) (0.12.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.19.3->gradio->spaces) (3.13.1)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.19.3->gradio->spaces) (4.66.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.0->gradio->spaces) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.0->gradio->spaces) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.0->gradio->spaces) (4.49.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.0->gradio->spaces) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.0->gradio->spaces) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.0->gradio->spaces) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas<3.0,>=1.0->gradio->spaces) (2023.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.10/dist-packages (from typer[all]<1.0,>=0.9->gradio->spaces) (8.1.7)
# Requirement already satisfied: colorama<0.5.0,>=0.4.3 in /usr/local/lib/python3.10/dist-packages (from typer[all]<1.0,>=0.9->gradio->spaces) (0.4.6)
# Requirement already satisfied: shellingham<2.0.0,>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from typer[all]<1.0,>=0.9->gradio->spaces) (1.5.4)
# Requirement already satisfied: rich<14.0.0,>=10.11.0 in /usr/local/lib/python3.10/dist-packages (from typer[all]<1.0,>=0.9->gradio->spaces) (13.7.0)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio->httpx>=0.20->spaces) (1.2.0)
# Requirement already satisfied: starlette<0.37.0,>=0.36.3 in /usr/local/lib/python3.10/dist-packages (from fastapi->gradio->spaces) (0.36.3)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio->spaces) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio->spaces) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio->spaces) (0.33.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio->spaces) (0.18.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib~=3.0->gradio->spaces) (1.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich<14.0.0,>=10.11.0->typer[all]<1.0,>=0.9->gradio->spaces) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich<14.0.0,>=10.11.0->typer[all]<1.0,>=0.9->gradio->spaces) (2.16.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich<14.0.0,>=10.11.0->typer[all]<1.0,>=0.9->gradio->spaces) (0.1.2)
# Installing collected packages: spaces
# Successfully installed spaces-0.23.2

# %%
# !python app.py
# Out:
# 2024-02-24 05:47:00.472065: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-02-24 05:47:00.472134: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-02-24 05:47:00.473933: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-02-24 05:47:02.257177: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# model_index.json: 100% 609/609 [00:00<00:00, 2.55MB/s]
# Fetching 19 files:   0% 0/19 [00:00<?, ?it/s]
# text_encoder/config.json: 100% 565/565 [00:00<00:00, 3.08MB/s]
#
# text_encoder_2/config.json: 100% 575/575 [00:00<00:00, 3.52MB/s]
#
# tokenizer/special_tokens_map.json: 100% 472/472 [00:00<00:00, 3.26MB/s]
#
# model.fp16.safetensors:   0% 0.00/246M [00:00<?, ?B/s]
#
# tokenizer/merges.txt:   0% 0.00/525k [00:00<?, ?B/s]
#
#
# model.fp16.safetensors:   0% 0.00/1.39G [00:00<?, ?B/s]
#
#
#
# scheduler/scheduler_config.json: 100% 479/479 [00:00<00:00, 1.94MB/s]
# Fetching 19 files:  11% 2/19 [00:00<00:04,  3.44it/s]
#
#
#
# tokenizer/tokenizer_config.json:   0% 0.00/737 [00:00<?, ?B/s]
# tokenizer/tokenizer_config.json: 100% 737/737 [00:00<00:00, 1.47MB/s]
#
#
#
#
# tokenizer/vocab.json:   0% 0.00/1.06M [00:00<?, ?B/s]
#
# tokenizer/merges.txt: 100% 525k/525k [00:00<00:00, 3.84MB/s]
#
#
#
# model.fp16.safetensors:   1% 10.5M/1.39G [00:00<00:13, 101MB/s]
#
# tokenizer_2/special_tokens_map.json: 100% 460/460 [00:00<00:00, 1.89MB/s]
#
# model.fp16.safetensors:  17% 41.9M/246M [00:00<00:01, 183MB/s]
#
#
# model.fp16.safetensors:   2% 31.5M/1.39G [00:00<00:08, 161MB/s]
#
# tokenizer_2/tokenizer_config.json: 100% 725/725 [00:00<00:00, 2.87MB/s]
#
#
# tokenizer_2/merges.txt:   0% 0.00/525k [00:00<?, ?B/s]
# model.fp16.safetensors:  26% 62.9M/246M [00:00<00:00, 187MB/s]
#
#
# model.fp16.safetensors:   4% 52.4M/1.39G [00:00<00:08, 163MB/s]
#
#
#
# tokenizer/vocab.json: 100% 1.06M/1.06M [00:00<00:00, 3.88MB/s]
#
#
# tokenizer_2/merges.txt: 100% 525k/525k [00:00<00:00, 4.14MB/s]
#
#
# unet/config.json: 100% 1.68k/1.68k [00:00<00:00, 7.32MB/s]
#
#
# diffusion_pytorch_model.fp16.safetensors:   0% 0.00/5.14G [00:00<?, ?B/s]
#
#
#
# vae/config.json: 100% 642/642 [00:00<00:00, 2.29MB/s]
#
# model.fp16.safetensors:  34% 83.9M/246M [00:00<00:01, 160MB/s]
#
#
#
# tokenizer_2/vocab.json:   0% 0.00/1.06M [00:00<?, ?B/s]
#
# diffusion_pytorch_model.fp16.safetensors:   0% 10.5M/5.14G [00:00<01:12, 71.0MB/s]
#
#
# model.fp16.safetensors:   5% 73.4M/1.39G [00:00<00:10, 126MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:   0% 21.0M/5.14G [00:00<01:17, 65.6MB/s]
# model.fp16.safetensors:  43% 105M/246M [00:00<00:01, 116MB/s]
#
#
#
# tokenizer_2/vocab.json: 100% 1.06M/1.06M [00:00<00:00, 4.08MB/s]
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:   0% 0.00/167M [00:00<?, ?B/s]
#
#
# model.fp16.safetensors:   7% 94.4M/1.39G [00:00<00:12, 105MB/s]
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:   0% 0.00/167M [00:00<?, ?B/s]
#
#
#
# diffusion_pytorch_model.fp16.safetensors:   6% 10.5M/167M [00:00<00:01, 95.1MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:   1% 41.9M/5.14G [00:00<01:51, 45.6MB/s]
# model.fp16.safetensors:  51% 126M/246M [00:03<00:06, 19.1MB/s]
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  13% 21.0M/167M [00:03<00:26, 5.49MB/s]
#
#
# model.fp16.safetensors:   8% 115M/1.39G [00:04<01:29, 14.2MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:   1% 52.4M/5.14G [00:04<09:50, 8.60MB/s]
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  13% 21.0M/167M [00:03<00:31, 4.59MB/s]
# model.fp16.safetensors:  55% 136M/246M [00:04<00:06, 16.0MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:   1% 62.9M/5.14G [00:04<07:34, 11.2MB/s]
# model.fp16.safetensors:  60% 147M/246M [00:05<00:05, 17.9MB/s]
#
#
# model.fp16.safetensors:   9% 126M/1.39G [00:05<01:20, 15.8MB/s]
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  19% 31.5M/167M [00:04<00:18, 7.47MB/s]
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  25% 41.9M/167M [00:04<00:10, 11.6MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:   1% 73.4M/5.14G [00:04<06:01, 14.0MB/s]
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  25% 41.9M/167M [00:04<00:11, 11.0MB/s]
# model.fp16.safetensors:  64% 157M/246M [00:05<00:04, 20.2MB/s]
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  31% 52.4M/167M [00:04<00:07, 14.5MB/s]
#
#
# model.fp16.safetensors:  10% 136M/1.39G [00:05<01:10, 17.8MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:   2% 83.9M/5.14G [00:05<04:28, 18.8MB/s]
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  31% 52.4M/167M [00:04<00:07, 15.3MB/s]
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  38% 62.9M/167M [00:04<00:05, 18.2MB/s]
#
#
# model.fp16.safetensors:  11% 147M/1.39G [00:05<01:00, 20.5MB/s]
# model.fp16.safetensors:  68% 168M/246M [00:05<00:03, 22.6MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:   2% 94.4M/5.14G [00:05<03:49, 21.9MB/s]
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  44% 73.4M/167M [00:04<00:04, 22.4MB/s]
#
#
# model.fp16.safetensors:  11% 157M/1.39G [00:05<00:49, 24.7MB/s]
# model.fp16.safetensors:  72% 178M/246M [00:05<00:02, 27.3MB/s]
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  38% 62.9M/167M [00:05<00:05, 19.0MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:   2% 105M/5.14G [00:05<03:01, 27.7MB/s]
#
#
# model.fp16.safetensors:  12% 168M/1.39G [00:05<00:40, 30.3MB/s]
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  50% 83.9M/167M [00:05<00:03, 27.7MB/s]
# model.fp16.safetensors:  77% 189M/246M [00:06<00:01, 32.6MB/s]
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  44% 73.4M/167M [00:05<00:03, 24.7MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:   2% 115M/5.14G [00:05<02:28, 33.8MB/s]
#
#
# model.fp16.safetensors:  13% 178M/1.39G [00:06<00:32, 37.7MB/s]
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  56% 94.4M/167M [00:05<00:02, 35.3MB/s]
# model.fp16.safetensors:  81% 199M/246M [00:06<00:01, 39.8MB/s]
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  50% 83.9M/167M [00:05<00:02, 30.4MB/s]
#
#
# model.fp16.safetensors:  14% 189M/1.39G [00:06<00:27, 43.8MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:   2% 126M/5.14G [00:05<02:07, 39.3MB/s]
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  63% 105M/167M [00:05<00:01, 41.4MB/s]
# model.fp16.safetensors:  85% 210M/246M [00:06<00:00, 42.8MB/s]
#
#
# model.fp16.safetensors:  14% 199M/1.39G [00:06<00:25, 46.8MB/s]
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  56% 94.4M/167M [00:05<00:02, 33.8MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:   3% 136M/5.14G [00:06<02:06, 39.6MB/s]
# model.fp16.safetensors:  89% 220M/246M [00:06<00:00, 45.7MB/s]
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  69% 115M/167M [00:05<00:01, 40.9MB/s]
#
#
# model.fp16.safetensors:  15% 210M/1.39G [00:06<00:23, 50.9MB/s]
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  63% 105M/167M [00:05<00:01, 38.8MB/s]
# model.fp16.safetensors:  94% 231M/246M [00:06<00:00, 48.5MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:   3% 147M/5.14G [00:06<02:00, 41.4MB/s]
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  75% 126M/167M [00:05<00:00, 43.4MB/s]
#
#
# model.fp16.safetensors:  16% 220M/1.39G [00:06<00:23, 50.6MB/s]
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  69% 115M/167M [00:05<00:01, 41.9MB/s]
# model.fp16.safetensors:  98% 241M/246M [00:06<00:00, 50.2MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:   3% 157M/5.14G [00:06<01:55, 42.9MB/s]
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  81% 136M/167M [00:06<00:00, 44.6MB/s]
#
#
# model.fp16.safetensors:  17% 231M/1.39G [00:06<00:23, 50.0MB/s]
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  75% 126M/167M [00:06<00:00, 43.8MB/s]
#
#
#
#
# model.fp16.safetensors: 100% 246M/246M [00:07<00:00, 34.4MB/s]
# Fetching 19 files:  21% 4/19 [00:07<00:33,  2.21s/it]
#
# diffusion_pytorch_model.fp16.safetensors:   3% 168M/5.14G [00:06<01:55, 43.1MB/s]
#
#
# model.fp16.safetensors:  17% 241M/1.39G [00:07<00:22, 51.4MB/s]
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  81% 136M/167M [00:06<00:00, 46.8MB/s]
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  94% 157M/167M [00:06<00:00, 50.5MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:   3% 178M/5.14G [00:06<01:45, 46.9MB/s]
#
#
# model.fp16.safetensors:  18% 252M/1.39G [00:07<00:21, 53.2MB/s]
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  88% 147M/167M [00:06<00:00, 48.5MB/s]
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors: 100% 167M/167M [00:06<00:00, 58.0MB/s]
#
#
# model.fp16.safetensors:  19% 262M/1.39G [00:07<00:20, 55.1MB/s]
#
# diffusion_pytorch_model.fp16.safetensors: 100% 167M/167M [00:06<00:00, 25.1MB/s]
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  94% 157M/167M [00:06<00:00, 52.8MB/s]
#
#
# model.fp16.safetensors:  20% 273M/1.39G [00:07<00:18, 61.3MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:   4% 199M/5.14G [00:07<01:32, 53.6MB/s]
#
#
#
# diffusion_pytorch_model.fp16.safetensors: 100% 167M/167M [00:06<00:00, 57.4MB/s]
#
#
# diffusion_pytorch_model.fp16.safetensors: 100% 167M/167M [00:06<00:00, 24.0MB/s]
#
#
# diffusion_pytorch_model.fp16.safetensors:   4% 210M/5.14G [00:07<01:21, 60.5MB/s]
#
#
# model.fp16.safetensors:  21% 294M/1.39G [00:07<00:15, 72.6MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:   4% 231M/5.14G [00:07<01:04, 76.4MB/s]
#
#
# model.fp16.safetensors:  23% 315M/1.39G [00:07<00:11, 94.5MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:   5% 241M/5.14G [00:07<00:59, 81.9MB/s]
#
#
# model.fp16.safetensors:  24% 336M/1.39G [00:08<00:10, 102MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:   5% 262M/5.14G [00:07<00:50, 96.0MB/s]
#
#
# model.fp16.safetensors:  26% 357M/1.39G [00:08<00:09, 104MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:   6% 283M/5.14G [00:08<00:48, 101MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:   6% 294M/5.14G [00:08<00:48, 99.4MB/s]
#
#
# model.fp16.safetensors:  27% 377M/1.39G [00:08<00:10, 100MB/s]
#
#
# model.fp16.safetensors:  28% 388M/1.39G [00:08<00:10, 96.0MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:   6% 315M/5.14G [00:08<00:48, 98.9MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:   6% 325M/5.14G [00:08<00:48, 98.8MB/s]
#
#
# model.fp16.safetensors:  29% 398M/1.39G [00:08<00:10, 92.1MB/s]
#
#
# model.fp16.safetensors:  29% 409M/1.39G [00:08<00:10, 89.6MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:   7% 336M/5.14G [00:08<00:51, 93.0MB/s]
#
#
# model.fp16.safetensors:  30% 419M/1.39G [00:09<00:11, 86.9MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:   7% 346M/5.14G [00:08<00:54, 88.5MB/s]
#
#
# model.fp16.safetensors:  31% 430M/1.39G [00:09<00:10, 90.3MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:   7% 357M/5.14G [00:08<00:52, 91.8MB/s]
#
#
# model.fp16.safetensors:  32% 440M/1.39G [00:09<00:10, 91.5MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:   7% 367M/5.14G [00:08<00:51, 92.5MB/s]
#
#
# model.fp16.safetensors:  32% 451M/1.39G [00:09<00:10, 93.4MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:   7% 377M/5.14G [00:09<00:54, 86.5MB/s]
#
#
# model.fp16.safetensors:  34% 472M/1.39G [00:09<00:08, 111MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:   8% 388M/5.14G [00:09<00:55, 85.2MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:   8% 398M/5.14G [00:09<00:57, 82.6MB/s]
#
#
# model.fp16.safetensors:  35% 493M/1.39G [00:09<00:08, 100MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:   8% 409M/5.14G [00:09<00:56, 83.4MB/s]
#
#
# model.fp16.safetensors:  36% 503M/1.39G [00:09<00:08, 99.6MB/s]
#
#
# model.fp16.safetensors:  37% 514M/1.39G [00:10<00:08, 98.0MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:   8% 430M/5.14G [00:09<01:04, 73.3MB/s]
#
#
# model.fp16.safetensors:  38% 524M/1.39G [00:10<00:11, 74.1MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:   9% 440M/5.14G [00:09<01:04, 72.7MB/s]
#
#
# model.fp16.safetensors:  38% 535M/1.39G [00:10<00:12, 68.3MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:   9% 461M/5.14G [00:10<00:58, 80.4MB/s]
#
#
# model.fp16.safetensors:  39% 545M/1.39G [00:10<00:11, 70.4MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:   9% 472M/5.14G [00:10<00:57, 81.3MB/s]
#
#
# model.fp16.safetensors:  40% 556M/1.39G [00:10<00:10, 77.1MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:   9% 482M/5.14G [00:10<00:54, 85.8MB/s]
#
#
# model.fp16.safetensors:  41% 566M/1.39G [00:10<00:10, 79.7MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  10% 493M/5.14G [00:10<00:57, 80.1MB/s]
#
#
# model.fp16.safetensors:  42% 577M/1.39G [00:11<00:11, 68.9MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  10% 503M/5.14G [00:10<00:56, 81.3MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  10% 514M/5.14G [00:10<00:57, 79.7MB/s]
#
#
# model.fp16.safetensors:  43% 598M/1.39G [00:11<00:09, 80.8MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  10% 535M/5.14G [00:10<00:45, 101MB/s]
#
#
# model.fp16.safetensors:  45% 619M/1.39G [00:11<00:09, 83.7MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  11% 556M/5.14G [00:11<00:46, 97.5MB/s]
#
#
# model.fp16.safetensors:  45% 629M/1.39G [00:11<00:09, 77.6MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  11% 566M/5.14G [00:11<00:50, 89.9MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  11% 577M/5.14G [00:11<00:49, 91.3MB/s]
#
#
# model.fp16.safetensors:  47% 650M/1.39G [00:11<00:08, 89.3MB/s]
#
#
# model.fp16.safetensors:  48% 661M/1.39G [00:11<00:08, 89.6MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  11% 587M/5.14G [00:11<00:51, 88.6MB/s]
#
#
# model.fp16.safetensors:  48% 671M/1.39G [00:12<00:07, 90.9MB/s]
#
#
# model.fp16.safetensors:  49% 682M/1.39G [00:14<00:47, 14.9MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  12% 608M/5.14G [00:14<04:21, 17.3MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  12% 629M/5.14G [00:14<02:52, 26.1MB/s]
#
#
# model.fp16.safetensors:  51% 703M/1.39G [00:14<00:29, 23.5MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  13% 650M/5.14G [00:14<02:10, 34.5MB/s]
#
#
# model.fp16.safetensors:  52% 724M/1.39G [00:14<00:20, 32.6MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  13% 661M/5.14G [00:14<01:53, 39.5MB/s]
#
#
# model.fp16.safetensors:  53% 734M/1.39G [00:15<00:17, 37.7MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  13% 671M/5.14G [00:14<01:38, 45.4MB/s]
#
#
# model.fp16.safetensors:  54% 744M/1.39G [00:15<00:14, 43.4MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  13% 682M/5.14G [00:14<01:26, 51.7MB/s]
#
#
# model.fp16.safetensors:  54% 755M/1.39G [00:15<00:12, 50.2MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  13% 692M/5.14G [00:14<01:15, 59.1MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  14% 703M/5.14G [00:15<01:06, 66.8MB/s]
#
#
# model.fp16.safetensors:  56% 776M/1.39G [00:15<00:09, 64.6MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  14% 713M/5.14G [00:15<01:00, 72.7MB/s]
#
#
# model.fp16.safetensors:  57% 797M/1.39G [00:15<00:07, 76.4MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  14% 734M/5.14G [00:15<00:48, 91.4MB/s]
#
#
# model.fp16.safetensors:  59% 818M/1.39G [00:15<00:06, 93.3MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  15% 755M/5.14G [00:17<03:15, 22.4MB/s]
#
#
# model.fp16.safetensors:  60% 839M/1.39G [00:17<00:21, 25.1MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  15% 776M/5.14G [00:17<02:17, 31.7MB/s]
#
#
# model.fp16.safetensors:  62% 860M/1.39G [00:17<00:15, 34.0MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  16% 797M/5.14G [00:17<01:42, 42.5MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  16% 807M/5.14G [00:17<01:30, 48.0MB/s]
#
#
# model.fp16.safetensors:  63% 870M/1.39G [00:18<00:14, 36.6MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  16% 818M/5.14G [00:17<01:24, 51.0MB/s]
#
#
# model.fp16.safetensors:  63% 881M/1.39G [00:18<00:12, 40.4MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  16% 828M/5.14G [00:18<01:16, 56.4MB/s]
#
#
# model.fp16.safetensors:  64% 891M/1.39G [00:18<00:10, 45.4MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  16% 839M/5.14G [00:18<01:10, 60.7MB/s]
#
#
# model.fp16.safetensors:  65% 902M/1.39G [00:18<00:09, 51.3MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  17% 849M/5.14G [00:18<01:06, 64.6MB/s]
#
#
# model.fp16.safetensors:  66% 912M/1.39G [00:18<00:08, 57.1MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  17% 870M/5.14G [00:19<01:44, 40.8MB/s]
#
#
# model.fp16.safetensors:  67% 933M/1.39G [00:19<00:11, 39.2MB/s]
#
#
# model.fp16.safetensors:  69% 954M/1.39G [00:19<00:08, 53.4MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  17% 891M/5.14G [00:19<01:17, 54.7MB/s]
#
#
# model.fp16.safetensors:  69% 965M/1.39G [00:19<00:07, 58.3MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  18% 902M/5.14G [00:19<01:12, 58.0MB/s]
#
#
# model.fp16.safetensors:  70% 975M/1.39G [00:19<00:06, 62.4MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  18% 912M/5.14G [00:19<01:08, 62.0MB/s]
#
#
# model.fp16.safetensors:  71% 986M/1.39G [00:20<00:06, 66.0MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  18% 923M/5.14G [00:19<01:03, 66.3MB/s]
#
#
# model.fp16.safetensors:  72% 996M/1.39G [00:20<00:05, 72.2MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  18% 933M/5.14G [00:19<00:58, 72.4MB/s]
#
#
# model.fp16.safetensors:  72% 1.01G/1.39G [00:20<00:05, 76.4MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  19% 954M/5.14G [00:19<00:48, 85.4MB/s]
#
#
# model.fp16.safetensors:  74% 1.03G/1.39G [00:20<00:03, 94.9MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  19% 965M/5.14G [00:20<00:47, 87.7MB/s]
#
#
# model.fp16.safetensors:  75% 1.04G/1.39G [00:20<00:03, 96.8MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  19% 986M/5.14G [00:20<00:40, 103MB/s]
#
#
# model.fp16.safetensors:  76% 1.06G/1.39G [00:20<00:02, 111MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  20% 1.01G/5.14G [00:20<00:35, 117MB/s]
#
#
# model.fp16.safetensors:  78% 1.08G/1.39G [00:20<00:02, 124MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  20% 1.03G/5.14G [00:20<00:30, 133MB/s]
#
#
# model.fp16.safetensors:  79% 1.10G/1.39G [00:20<00:02, 133MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  20% 1.05G/5.14G [00:20<00:27, 147MB/s]
#
#
# model.fp16.safetensors:  81% 1.12G/1.39G [00:21<00:01, 139MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  21% 1.07G/5.14G [00:20<00:27, 150MB/s]
#
#
# model.fp16.safetensors:  82% 1.14G/1.39G [00:21<00:01, 144MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  21% 1.09G/5.14G [00:20<00:25, 160MB/s]
#
#
# model.fp16.safetensors:  84% 1.16G/1.39G [00:21<00:01, 149MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  22% 1.11G/5.14G [00:20<00:25, 159MB/s]
#
#
# model.fp16.safetensors:  85% 1.18G/1.39G [00:21<00:01, 149MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  22% 1.13G/5.14G [00:21<00:27, 147MB/s]
#
#
# model.fp16.safetensors:  87% 1.21G/1.39G [00:21<00:01, 139MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  22% 1.15G/5.14G [00:21<00:28, 142MB/s]
#
#
# model.fp16.safetensors:  88% 1.23G/1.39G [00:21<00:01, 134MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  23% 1.17G/5.14G [00:21<00:29, 136MB/s]
#
#
# model.fp16.safetensors:  90% 1.25G/1.39G [00:21<00:01, 133MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  23% 1.20G/5.14G [00:21<00:29, 132MB/s]
#
#
# model.fp16.safetensors:  91% 1.27G/1.39G [00:22<00:00, 125MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  24% 1.22G/5.14G [00:21<00:30, 129MB/s]
#
#
# model.fp16.safetensors:  93% 1.29G/1.39G [00:22<00:00, 123MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  24% 1.24G/5.14G [00:21<00:29, 131MB/s]
#
#
# model.fp16.safetensors:  94% 1.31G/1.39G [00:22<00:00, 123MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  25% 1.26G/5.14G [00:22<00:31, 124MB/s]
#
#
# model.fp16.safetensors:  96% 1.33G/1.39G [00:22<00:00, 123MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  25% 1.28G/5.14G [00:22<00:31, 122MB/s]
#
#
# model.fp16.safetensors:  97% 1.35G/1.39G [00:22<00:00, 123MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  25% 1.30G/5.14G [00:22<00:30, 125MB/s]
#
#
# model.fp16.safetensors:  99% 1.37G/1.39G [00:23<00:00, 124MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  26% 1.32G/5.14G [00:22<00:30, 127MB/s]
#
#
# model.fp16.safetensors: 100% 1.39G/1.39G [00:23<00:00, 59.9MB/s]
# Fetching 19 files:  32% 6/19 [00:23<01:03,  4.87s/it]
#
# diffusion_pytorch_model.fp16.safetensors:  26% 1.34G/5.14G [00:22<00:31, 120MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  27% 1.36G/5.14G [00:22<00:28, 131MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  27% 1.38G/5.14G [00:23<00:26, 142MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  27% 1.41G/5.14G [00:23<00:25, 149MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  28% 1.43G/5.14G [00:23<00:23, 159MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  28% 1.45G/5.14G [00:23<00:21, 170MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  29% 1.47G/5.14G [00:23<00:21, 173MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  29% 1.49G/5.14G [00:23<00:21, 172MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  29% 1.51G/5.14G [00:23<00:20, 176MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  30% 1.53G/5.14G [00:23<00:19, 184MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  30% 1.56G/5.14G [00:24<00:18, 198MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  31% 1.58G/5.14G [00:24<00:17, 200MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  31% 1.61G/5.14G [00:24<00:16, 210MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  32% 1.65G/5.14G [00:24<00:15, 224MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  33% 1.68G/5.14G [00:24<00:14, 233MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  33% 1.71G/5.14G [00:24<00:13, 247MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  34% 1.74G/5.14G [00:24<00:13, 244MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  35% 1.77G/5.14G [00:24<00:13, 242MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  35% 1.80G/5.14G [00:25<00:13, 243MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  36% 1.84G/5.14G [00:25<00:13, 237MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  36% 1.87G/5.14G [00:25<00:13, 237MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  37% 1.90G/5.14G [00:25<00:13, 239MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  38% 1.93G/5.14G [00:25<00:13, 238MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  38% 1.96G/5.14G [00:25<00:13, 229MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  39% 1.99G/5.14G [00:25<00:13, 234MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  39% 2.02G/5.14G [00:25<00:13, 232MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  40% 2.06G/5.14G [00:26<00:13, 236MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  41% 2.09G/5.14G [00:26<00:12, 242MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  41% 2.12G/5.14G [00:26<00:12, 241MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  42% 2.15G/5.14G [00:26<00:12, 243MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  42% 2.18G/5.14G [00:26<00:12, 241MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  43% 2.21G/5.14G [00:26<00:11, 247MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  44% 2.24G/5.14G [00:26<00:11, 244MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  44% 2.28G/5.14G [00:26<00:11, 242MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  45% 2.31G/5.14G [00:27<00:11, 236MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  46% 2.34G/5.14G [00:27<00:11, 240MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  46% 2.37G/5.14G [00:28<00:44, 62.4MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  47% 2.39G/5.14G [00:28<00:38, 71.7MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  47% 2.42G/5.14G [00:28<00:29, 93.2MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  48% 2.45G/5.14G [00:29<00:22, 118MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  48% 2.49G/5.14G [00:29<00:18, 140MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  49% 2.52G/5.14G [00:29<00:17, 153MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  50% 2.55G/5.14G [00:29<00:15, 171MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  50% 2.58G/5.14G [00:29<00:13, 186MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  51% 2.61G/5.14G [00:29<00:13, 194MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  51% 2.64G/5.14G [00:29<00:12, 203MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  52% 2.67G/5.14G [00:29<00:11, 208MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  53% 2.71G/5.14G [00:30<00:11, 212MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  53% 2.74G/5.14G [00:30<00:10, 225MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  54% 2.77G/5.14G [00:30<00:10, 233MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  55% 2.80G/5.14G [00:30<00:09, 234MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  55% 2.83G/5.14G [00:30<00:09, 234MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  56% 2.86G/5.14G [00:30<00:09, 236MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  56% 2.89G/5.14G [00:30<00:09, 240MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  57% 2.93G/5.14G [00:31<00:09, 237MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  58% 2.96G/5.14G [00:31<00:09, 239MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  58% 2.99G/5.14G [00:31<00:08, 245MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  59% 3.02G/5.14G [00:31<00:08, 244MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  59% 3.05G/5.14G [00:31<00:08, 244MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  60% 3.08G/5.14G [00:31<00:08, 249MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  61% 3.11G/5.14G [00:31<00:08, 251MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  61% 3.15G/5.14G [00:31<00:07, 251MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  62% 3.18G/5.14G [00:32<00:07, 247MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  62% 3.21G/5.14G [00:32<00:07, 249MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  63% 3.24G/5.14G [00:32<00:07, 252MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  64% 3.27G/5.14G [00:32<00:07, 252MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  64% 3.30G/5.14G [00:32<00:07, 251MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  65% 3.33G/5.14G [00:32<00:07, 251MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  66% 3.37G/5.14G [00:32<00:07, 251MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  66% 3.40G/5.14G [00:32<00:06, 253MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  67% 3.43G/5.14G [00:33<00:06, 249MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  67% 3.46G/5.14G [00:33<00:06, 249MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  68% 3.49G/5.14G [00:33<00:06, 251MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  69% 3.52G/5.14G [00:33<00:06, 249MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  69% 3.55G/5.14G [00:33<00:06, 247MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  70% 3.59G/5.14G [00:33<00:06, 253MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  70% 3.62G/5.14G [00:33<00:05, 257MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  71% 3.65G/5.14G [00:33<00:05, 253MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  72% 3.68G/5.14G [00:34<00:05, 252MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  72% 3.71G/5.14G [00:34<00:05, 243MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  73% 3.74G/5.14G [00:34<00:05, 254MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  74% 3.77G/5.14G [00:34<00:05, 247MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  74% 3.81G/5.14G [00:34<00:05, 235MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  75% 3.84G/5.14G [00:34<00:05, 235MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  75% 3.87G/5.14G [00:34<00:06, 199MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  76% 3.90G/5.14G [00:35<00:06, 202MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  76% 3.92G/5.14G [00:35<00:06, 180MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  77% 3.94G/5.14G [00:35<00:06, 178MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  77% 3.96G/5.14G [00:35<00:06, 172MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  78% 3.98G/5.14G [00:35<00:06, 174MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  78% 4.01G/5.14G [00:35<00:06, 172MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  79% 4.04G/5.14G [00:35<00:05, 187MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  79% 4.07G/5.14G [00:36<00:05, 198MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  80% 4.09G/5.14G [00:36<00:05, 191MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  80% 4.11G/5.14G [00:36<00:05, 191MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  80% 4.13G/5.14G [00:36<00:05, 188MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  81% 4.15G/5.14G [00:36<00:05, 190MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  81% 4.17G/5.14G [00:39<00:37, 25.5MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  82% 4.20G/5.14G [00:39<00:23, 39.1MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  82% 4.24G/5.14G [00:39<00:16, 56.0MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  83% 4.27G/5.14G [00:39<00:11, 76.7MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  84% 4.30G/5.14G [00:39<00:08, 98.0MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  84% 4.33G/5.14G [00:39<00:06, 116MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  85% 4.36G/5.14G [00:39<00:05, 134MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  86% 4.39G/5.14G [00:39<00:04, 153MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  86% 4.42G/5.14G [00:40<00:04, 172MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  87% 4.46G/5.14G [00:40<00:03, 184MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  87% 4.49G/5.14G [00:40<00:03, 197MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  88% 4.52G/5.14G [00:40<00:02, 210MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  89% 4.55G/5.14G [00:40<00:02, 218MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  89% 4.58G/5.14G [00:40<00:02, 231MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  90% 4.61G/5.14G [00:40<00:02, 233MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  90% 4.65G/5.14G [00:41<00:02, 239MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  91% 4.68G/5.14G [00:41<00:01, 247MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  92% 4.71G/5.14G [00:41<00:01, 256MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  92% 4.74G/5.14G [00:41<00:01, 260MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  93% 4.77G/5.14G [00:41<00:01, 256MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  94% 4.80G/5.14G [00:41<00:01, 231MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  94% 4.83G/5.14G [00:41<00:01, 234MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  95% 4.87G/5.14G [00:41<00:01, 236MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  95% 4.90G/5.14G [00:42<00:01, 238MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  96% 4.93G/5.14G [00:42<00:00, 239MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  97% 4.96G/5.14G [00:42<00:00, 234MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  97% 4.99G/5.14G [00:42<00:00, 231MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  98% 5.02G/5.14G [00:42<00:00, 234MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  98% 5.05G/5.14G [00:42<00:00, 235MB/s]
#
# diffusion_pytorch_model.fp16.safetensors:  99% 5.09G/5.14G [00:42<00:00, 237MB/s]
#
# diffusion_pytorch_model.fp16.safetensors: 100% 5.14G/5.14G [00:43<00:00, 119MB/s]
# Fetching 19 files: 100% 19/19 [00:44<00:00,  2.32s/it]
# Loading pipeline components...: 100% 7/7 [00:02<00:00,  2.38it/s]
# /usr/local/lib/python3.10/dist-packages/spaces/zero/decorator.py:76: UserWarning: `enable_queue` parameter is now ignored and always set to `True`
#   warnings.warn("`enable_queue` parameter is now ignored and always set to `True`")
# Running on local URL:  http://127.0.0.1:7860
# Running on public URL: https://d5e036c47575a01cf3.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# sdxl_lightning_4step_unet.safetensors: 100% 5.14G/5.14G [00:56<00:00, 90.1MB/s]
# 100% 4/4 [00:02<00:00,  1.39it/s]
# 100% 4/4 [00:01<00:00,  2.65it/s]
# 100% 4/4 [00:01<00:00,  2.63it/s]
