# %% [markdown]
# <a href="https://colab.research.google.com/github/koji/GoogleColab/blob/main/smolagents_with_ollama.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q git+https://github.com/HawkClaws/oyama.git ollama
# Out:
#   Preparing metadata (setup.py) ... done
# ...

# %%
from oyama import oyama
import ollama
model_path = "phi4"
model_name = oyama.run(model_path)
# Out:
# Streaming output truncated to the last 5000 lines.
# pulling f5d6f49c6477... 100% ▕████████████████▏  486 B
# verifying sha256 digest ⠏ pulling manifest
# pulling fd7b6731c33c... 100% ▕████████████████▏ 9.1 GB
# pulling 32695b892af8... 100% ▕████████████████▏  275 B
# pulling fa8235e5b48f... 100% ▕████████████████▏ 1.1 KB
# pulling 45a1c652dddc... 100% ▕████████████████▏   82 B
# pulling f5d6f49c6477... 100% ▕████████████████▏  486 B
# verifying sha256 digest ⠋ pulling manifest
# pulling fd7b6731c33c... 100% ▕████████████████▏ 9.1 GB
# pulling 32695b892af8... 100% ▕████████████████▏  275 B
# pulling fa8235e5b48f... 100% ▕████████████████▏ 1.1 KB
# pulling 45a1c652dddc... 100% ▕████████████████▏   82 B
# pulling f5d6f49c6477... 100% ▕████████████████▏  486 B
# verifying sha256 digest ⠙ pulling manifest
# pulling fd7b6731c33c... 100% ▕████████████████▏ 9.1 GB
# pulling 32695b892af8... 100% ▕████████████████▏  275 B
# pulling fa8235e5b48f... 100% ▕████████████████▏ 1.1 KB
# ...

# %%
# !pip install litellm
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 58.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.4/76.4 kB 7.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 59.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: httpx
#     Found existing installation: httpx 0.28.1
#     Uninstalling httpx-0.28.1:
#       Successfully uninstalled httpx-0.28.1
# ...

# %%
import litellm
# Out:
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_config.py:345: UserWarning: Valid config keys have changed in V2:
# * 'fields' has been removed
#   warnings.warn(message, UserWarning)

# %%
print(dir(litellm))
# Out:
# ['AI21ChatConfig', 'AI21Config', 'ALL_LITELLM_RESPONSE_TYPES', 'APIConnectionError', 'APIError', 'APIResponseValidationError', 'AZURE_DEFAULT_API_VERSION', 'AdapterCompletionStreamWrapper', 'AdapterItem', 'AiohttpOpenAIChatConfig', 'AlephAlphaConfig', 'AlertingConfig', 'AllEmbeddingInputValues', 'AllMessageValues', 'AllPromptValues', 'AllowedFailsPolicy', 'AmazonAI21Config', 'AmazonAnthropicClaude3Config', 'AmazonAnthropicConfig', 'AmazonBedrockGlobalConfig', 'AmazonCohereChatConfig', 'AmazonCohereConfig', 'AmazonConverseConfig', 'AmazonLlamaConfig', 'AmazonMistralConfig', 'AmazonStability3Config', 'AmazonStabilityConfig', 'AmazonTitanConfig', 'AmazonTitanG1Config', 'AmazonTitanMultimodalEmbeddingG1Config', 'AmazonTitanV2Config', 'AnthropicChatCompletion', 'AnthropicConfig', 'AnthropicExperimentalPassThroughConfig', 'AnthropicTextConfig', 'Any', 'Assistant', 'AssistantDeleted', 'AssistantEventHandler', 'AssistantStreamManager', 'AssistantToolParam', 'AssistantsTypedDict', 'AsyncAssis
# ...

# %%
# !pip show litellm
# Out:
# Name: litellm
# Version: 1.58.2
# Summary: Library to easily interface with LLM API providers
# Home-page: https://litellm.ai
# Author: BerriAI
# Author-email:
# License: MIT
# Location: /usr/local/lib/python3.11/dist-packages
# Requires: aiohttp, click, httpx, importlib-metadata, jinja2, jsonschema, openai, pydantic, python-dotenv, tiktoken, tokenizers
# Required-by:

# %%
# !pip install smolagents
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.9/89.9 kB 2.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.8/70.8 kB 3.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 MB 16.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 321.4/321.4 kB 21.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.1/13.1 MB 78.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.7/81.7 kB 7.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.8/94.8 kB 8.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 98.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 116.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.2/73.2 kB 6.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.3/62.3 kB 5.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: markupsafe
#     Found existing installation: MarkupSafe 3.0.2
# ...

# %%
from smolagents import LiteLLMModel

model = LiteLLMModel(
    model_id="ollama/phi4",
    # api_base="http://localhost:11434",
    # api_key="YOUR_API_KEY"
)

# %%
from smolagents import CodeAgent, DuckDuckGoSearchTool

agent = CodeAgent(tools=[DuckDuckGoSearchTool()], model=model)

agent.run("How many seconds would it take for a leopard at full speed to run through Pont des Arts?")
# Out:
# ╭────────────────────────────────────────────────────────────────────────────────────────────── New run ───────────────────────────────────────────────────────────────────────────────────────────────╮
# │                                                                                                                                                                                                      │
# │ How many seconds would it take for a leopard at full speed to run through Pont des Arts?                                                                                                             │
# │                                                                                                                                                                                                      │
# ...

# %%
agent.run("東京から大阪までは車でどれ位掛かりますか？")
# Out:
# ╭────────────────────────────────────────────────────────────────────────────────────────────── New run ───────────────────────────────────────────────────────────────────────────────────────────────╮
# │                                                                                                                                                                                                      │
# │ 東京から大阪までは車でどれ位掛かりますか？                                                                                                                                                           │
# │                                                                                                                                                                                                      │
# ╰─ LiteLLMModel - ollama/phi4 ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ...
